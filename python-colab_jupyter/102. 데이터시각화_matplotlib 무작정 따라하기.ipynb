# %%
import matplotlib.pyplot as plt

# %%
plt.plot([10,20,30,40])
plt.show()

# %%
plt.plot([1,2,3,4,],[10,23,34,45])
plt.title('multi_ZZang')
plt.show()

# %%
plt.title('multi_ZZang')
plt.plot([1,2,3,4],[10,23,34,45], label='abc')
plt.plot([1,2,3,4],[40,30,20,10], label='desc')
plt.legend()
plt.show()

# %%
plt.title('multi_ZZang')
plt.plot([1,2,3,4],[10,23,34,45], color='green', label='abc')
plt.plot([1,2,3,4],[40,30,20,10], 'pink', label='desc')
plt.legend()
plt.show()

# %%
plt.title('marker')
plt.plot([1,2,3,4],[10,23,34,45], 'r.', label='circle')
plt.plot([1,2,3,4],[40,30,20,10], 'b^', label='triangle_up')
plt.legend()
plt.show()

# %% [markdown]
# ### 데이터 읽어 최고 기온 데이터 출력하기

# %%
import csv
f= open('./data/seoul_book.csv')
data = csv.reader(f)
next(data)
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
for row in data:
    print(row[-1])
# Out:
# 20.7
# 22
# 21.3
# 22
# 25.4
# 21.3
# 16.1
# 14.9
# 21.1
# 24.1
# 20.4
# 17.4
# 21.3
# 20.6
# 20.9
# 20.2
# 21.6
# 20.9
# 21.3
# 22.7
# 19.9
# 19.6
# 16.3
# 17.1
# 18.7
# 18.2
# 20.7
# 19.6
# 20
# 20.1
# 20.3
# 21.3
# 21.1
# 11.1
# 13.6
# 17
# 18.1
# 12.4
# 9.4
# 11.9
# 13.2
# 13.4
# 14.9
# 16.4
# 15.2
# 17.6
# 12.6
# 11.7
# 6.7
# 4.3
# 7.1
# 6.2
# 11.2
# 9.9
# 5.9
# -0.7
# 1.5
# 1.9
# 2
# 2.9
# -2.4
# 1.4
# 3.4
# 6.1
# 1.3
# 2.6
# 5.8
# 1.9
# 6.6
# 8.1
# 4.3
# 0.6
# 3.8
# 9
# 6.4
# -5.1
# -2.4
# -2.1
# -0.4
# -0.2
# 1.9
# -8.1
# -10.2
# -9.4
# 0.9
# 6.8
# 6.4
# -0.7
# -1.9
# -4.4
# -6.1
# -2.1
# -1.3
# -3
# -2.9
# -1.7
# -0.1
# 2.9
# -1.2
# -0.9
# 2
# 3.3
# 4.8
# 4.5
# 4.7
# 0.1
# 0.9
# -4.5
# -3.6
# 2.8
# 2.8
# 2.3
# -6.1
# -5.1
# -2.7
# 0.1
# 0.3
# -0.6
# 0
# -1.3
# 0.8
# 0.8
# 6.2
# 1.6
# -0.2
# -5.4
# -4.1
# -5.5
# -5.7
# -3.7
# 1.3
# -4.1
# -2.5
# -2.8
# -1.2
# 1.3
# 2.3
# 2
# -1.4
# -1.6
# 0.3
# 5.5
# 7.3
# 5.1
# 5.4
# 2.7
# 1.7
# 0.8
# 4.1
# 8.4
# 6.3
# 5.6
# 4
# 0.1
# 4.9
# ...

# %%
import csv
f= open('./data/seoul_book.csv')
data = csv.reader(f)
next(data)
result=[]


for row in data:
    if row[-1] != '': # 공백이 아니라면
        result.append(float(row[-1]))

print(result)
# Out:
# [20.7, 22.0, 21.3, 22.0, 25.4, 21.3, 16.1, 14.9, 21.1, 24.1, 20.4, 17.4, 21.3, 20.6, 20.9, 20.2, 21.6, 20.9, 21.3, 22.7, 19.9, 19.6, 16.3, 17.1, 18.7, 18.2, 20.7, 19.6, 20.0, 20.1, 20.3, 21.3, 21.1, 11.1, 13.6, 17.0, 18.1, 12.4, 9.4, 11.9, 13.2, 13.4, 14.9, 16.4, 15.2, 17.6, 12.6, 11.7, 6.7, 4.3, 7.1, 6.2, 11.2, 9.9, 5.9, -0.7, 1.5, 1.9, 2.0, 2.9, -2.4, 1.4, 3.4, 6.1, 1.3, 2.6, 5.8, 1.9, 6.6, 8.1, 4.3, 0.6, 3.8, 9.0, 6.4, -5.1, -2.4, -2.1, -0.4, -0.2, 1.9, -8.1, -10.2, -9.4, 0.9, 6.8, 6.4, -0.7, -1.9, -4.4, -6.1, -2.1, -1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, 1.6, -0.2, -5.4, -4.1, -5.5, -5.7, -3.7, 1.3, -4.1, -2.5, -2.8, -1.2, 1.3, 2.3, 2.0, -1.4, -1.6, 0.3, 5.5, 7.3, 5.1, 5.4, 2.7, 1.7, 0.8, 4.1, 8.4, 6.3, 5.6, 4.0, 0.1, 4.9, 4.0, 7.9, 7.9, 2.2, 1.9, 1.5, 1.5, 1.8, 2.6, 3.8, 6.7, 11.8, 13.5, 15.7, 10.7, 7.9, 4.3, 6.0, 12.5, 17.0, 14.7, 11.4, 7.4, 8.0, 15.5
# ...

# %%
plt.plot(result)
plt.show()

# %% [markdown]
# [참고]

# %%
s = 'hello python'
print(s.split())
# Out:
# ['hello', 'python']

# %%
date = '2021-12-28'
type(date)
# Out:
# str

# %%
print(date.split('-'))
# Out:
# ['2021', '12', '28']

# %%
print(date[0])
print(date[1])
print(date[2])
print(date[3])
print(date[4])
# Out:
# 2
# 0
# 2
# 1
# -

# %%
print(date.split('-')[0])
print(date.split('-')[1])
print(date.split('-')[2])
# Out:
# 2021
# 12
# 28

# %%
a = date.split('-')
a
# Out:
# ['2021', '12', '28']

# %%
print(a[0])
print(a[1])
print(a[2])
# Out:
# 2021
# 12
# 28

# %% [markdown]
# ### 주어진 데이터에서 8월의 최고 기온 데이터 시각화 하기

# %%
for row in data:
    if row[-1]!='':
        if row[0].split('-')[1] == '08':
            result.append(float(row[-1]))

# %%
plt.plot(result, 'blue')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 내 생일 최고 기온 데이터 시각화하기

for row in data:
    if row[-1]!='':
        if row[0].split('-')[1] == '03' & row[0].splil('-')[2] == '02':
            result.append(float(row[-1]))

# %%
plt.plot(result, 'red')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## 한글 폰트 사용(my_modules 에 복붙)

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False # 한글폰트 사용시 -부호 표현하기
plt.title('마이버스데이 기온 변화 그래프')
# Out:
# Text(0.5, 1.0, '마이버스데이 기온 변화 그래프')

# %%
plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False # 한글폰트 사용시 -부호 표현하기
plt.title('마이버스데이 기온 변화 그래프')

plt.plot(result, 'red')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import csv

f = open('./data/seoul.csv', 'r', encoding='utf-8')
data = csv.reader(f)
next(data)
# Out:
# ['\t\t지점번호',
#  '지점명',
#  '일시',
#  '평균기온(℃)',
#  '평균최고기온(℃)',
#  '최고기온(℃)',
#  '\t최고기온일자',
#  '평균최저기온(℃)',
#  '최저기온(℃)',
#  '최저기온일자']

# %%
for row in data:
    print(row[5])
    print(row[6])
# Out:
# 7.3
# 2008-01-06
# 10.5
# 2008-02-22
# 19.8
# 2008-03-21
# 28.0
# 2008-04-19
# 28.5
# 2008-05-29
# 29.6
# 2008-06-20
# 32.9
# 2008-07-09
# 35.4
# 2008-08-08
# 32.0
# 2008-09-17
# 28.3
# 2008-10-18
# 18.4
# 2008-11-06
# 13.3
# 2008-12-10
# 12.2
# 2009-01-30
# 16.1
# 2009-02-13
# 22.2
# 2009-03-21
# 25.8
# 2009-04-19
# 31.0
# 2009-05-28
# 32.4
# 2009-06-27
# 32.4
# 2009-07-16
# 34.4
# 2009-08-16
# 29.9
# 2009-09-06
# 26.4
# 2009-10-01
# 21.8
# 2009-11-09
# 10.1
# 2009-12-01
# 8.4
# 2010-01-20
# 17.9
# 2010-02-24
# 14.2
# 2010-03-30
# 20.7
# 2010-04-20
# 28.6
# 2010-05-21
# 32.7
# 2010-06-10
# 32.3
# 2010-07-20
# 33.8
# 2010-08-05
# 31.4
# 2010-09-01
# 24.2
# 2010-10-09
# 17.4
# 2010-11-13
# 13.5
# 2010-12-02
# 0.3
# 2011-01-14
# 13.2
# 2011-02-26
# 16.8
# 2011-03-31
# 19.0
# 2011-04-15
# 31.2
# 2011-05-29
# 32.9
# 2011-06-19
# 34.1
# 2011-07-18
# 34.1
# 2011-08-05
# 32.4
# 2011-09-02
# 23.4
# 2011-10-13
# 25.9
# 2011-11-05
# 9.1
# 2011-12-03
# 8.4
# 2012-01-19
# 12.1
# 2012-02-22
# ...

# %%
import csv

f = open('./data/seoul.csv', 'r', encoding='utf-8')
data = csv.reader(f)
next(data)
result=[]

for row in data:
    if row[5] != '':
        if row[6].split('-')[1] == '03':
            result.append(float(row[5]))

print(result)
# Out:
# [19.8, 22.2, 14.2, 16.8, 16.2, 23.8, 23.8, 21.9, 21.4, 18.9, 22.1, 17.6, 20.6, 22.9]

# %%
plt.plot(result, 'Gold')
plt.show()

# %%
import csv
from pandas import DataFrame as pd

f = open('./data/seoul_day.csv', encoding='cp949')
data = csv.reader(f)
next(data)
result = []

for row in data:
    if row[4] != '':
        if row[0].split('-')[1] == '03' and row[0].split('-')[2] == '02':
            result.append(float(row[4]))

print(result)
# Out:
# [0.1, 4.4, 3.5, 1.1, 9.8, 0.9, 14.7, 2.4, -1.7, 5.4, 4.5, 12.6, 4.5, 7.5, 5.7, 5.7, 1.9, 0.9, 7.5, 7.6, 9.6, 1.0, 6.1, 5.9, 11.6, -0.1, 2.2, 7.9, -3.4, 15.2, 10.4, 11.4, 5.5, 9.4, 8.9, 10.3, 13.4, 5.1, 10.5, 10.8, 4.8, 4.8, 10.6, 26.1, 25.1, 17.8, 22.6, 24.4, 26.3, 21.0, 20.5, 24.7, 23.6, 25.0, 21.8, 17.0, 28.1, 22.5, 19.4, 28.2, 19.2, 22.9, 19.4, 22.9, 19.6, 18.1, 19.9, 25.5, 17.3, 19.9, 22.9, 22.5, 16.9, 23.1, 19.0, 24.3, 21.0, 23.6, 24.9, 22.7, 19.5, 19.4, 26.0, 24.1, 22.0, 22.3, 21.5, 23.0, 21.0, 19.6, 22.5, 12.0, 18.4, 21.8, 19.7, 26.5, 26.1, 23.4, 27.5, 20.6, 21.8, 24.1, 26.7, 22.3, 24.0, 18.6, 22.8, 25.5, 21.9, 27.6, 17.2]

# %%
plt.plot(result, 'Gold')
plt.show()
